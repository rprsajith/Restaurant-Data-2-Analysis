# %%
import numpy as np

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/i2.csv')

# %%
df.head()
# Out:
#          Date            Timestamp  Invoice No.        Item Name  Price  Qty.  \
# 0  2023-06-30  2023-06-30 22:47:50        26190    Mineral Water   20.0   1.0
# 1  2023-06-30  2023-06-30 22:25:11        26189  Chapathi (2 No)   50.0   1.0
# 2  2023-06-30  2023-06-30 22:25:11        26189             Roti   40.0   1.0
# 3  2023-06-30  2023-06-30 22:25:11        26189   Mushroom Pulao  140.0   1.0
# 4  2023-06-30  2023-06-30 22:25:11        26189   Veg Fried Rice  130.0   1.0
#
#    Sub Total  Discount  Tax  Final Total  Table No. Server Name  Covers  \
# 0       20.0       0.0  1.0         21.0        1.0      biller       0
# 1       50.0       0.0  2.5         52.5        9.0      biller       0
# 2       40.0       0.0  2.0         42.0        9.0      biller       0
# 3      140.0       0.0  7.0        147.0        9.0      biller       0
# 4      130.0       0.0  6.5        136.5        9.0      biller       0
#
#   Variation             Category  HSN
# ...

# %%
df.tail()
# Out:
#             Date            Timestamp  Invoice No.  \
# 8374  2023-04-01  2023-04-01 13:16:03        23465
# 8375  2023-04-01  2023-04-01 13:16:03        23465
# 8376  2023-04-01  2023-04-01 13:16:03        23465
# 8377  2023-04-01  2023-04-01 13:16:03        23465
# 8378  2023-04-01  2023-04-01 13:16:03        23465
#
#                         Item Name  Price  Qty.  Sub Total  Discount   Tax  \
# 8374         Paneer Butter Masala  150.0   2.0      300.0       0.0  15.0
# 8375  Schewan  Chicken Fried Rice  160.0   1.0      160.0       0.0   8.0
# 8376      Schezwan Egg Fried Rice  140.0   1.0      140.0       0.0   7.0
# 8377            Chicken Kati Roll  120.0   1.0      120.0       0.0   6.0
# 8378             Soft Drink 600ml   40.0   2.0       80.0       0.0   4.0
#
#       Final Total  Table No. Server Name  Covers Variation  \
# 8374        315.0       20.0      biller       0       NaN
# 8375        168.0       20.0      biller       0       NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8379 entries, 0 to 8378
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         8379 non-null   object
#  1   Timestamp    8379 non-null   object
#  2   Invoice No.  8379 non-null   int64
#  3   Item Name    8379 non-null   object
#  4   Price        8379 non-null   float64
#  5   Qty.         8379 non-null   float64
#  6   Sub Total    8379 non-null   float64
#  7   Discount     8379 non-null   float64
#  8   Tax          8379 non-null   float64
#  9   Final Total  8379 non-null   float64
#  10  Table No.    8371 non-null   float64
#  11  Server Name  8379 non-null   object
#  12  Covers       8379 non-null   int64
#  13  Variation    7 non-null      object
#  14  Category     8379 non-null   object
#  15  HSN          0 non-null      float64
# dtypes: float64(8), int64(2), object(6)
# memory usage: 1.0+ MB

# %%
df.describe()
# Out:
#         Invoice No.        Price         Qty.     Sub Total     Discount  \
# count   8379.000000  8379.000000  8379.000000   8379.000000  8379.000000
# mean   24828.808927   111.161594     1.306958    136.245733     1.108451
# std      771.793237    65.076360     0.949960    257.877211     6.658616
# min    23465.000000    12.000000     1.000000     12.000000     0.000000
# 25%    24173.000000    50.000000     1.000000     60.000000     0.000000
# 50%    24830.000000   120.000000     1.000000    140.000000     0.000000
# 75%    25491.500000   160.000000     1.000000    170.000000     0.000000
# max    26190.000000   770.000000    28.000000  21560.000000   192.000000
#
#                Tax   Final Total    Table No.  Covers  HSN
# count  8379.000000   8379.000000  8371.000000  8379.0  0.0
# mean      6.749999    141.887281    16.278461     0.0  NaN
# std      12.845963    269.751689    16.129123     0.0  NaN
# min       0.000000     12.600000     1.000000     0.0  NaN
# ...

# %%
df.shape
# Out:
# (8379, 16)

# %%
df.isnull().sum()
# Out:
# Date              0
# Timestamp         0
# Invoice No.       0
# Item Name         0
# Price             0
# Qty.              0
# Sub Total         0
# Discount          0
# Tax               0
# Final Total       0
# Table No.         8
# Server Name       0
# Covers            0
# Variation      8372
# Category          0
# HSN            8379
# dtype: int64

# %%
df['Invoice No.'].unique()
# Out:
# array([26190, 26189, 26188, ..., 23467, 23466, 23465])

# %%
df['Invoice No.'].nunique()
# Out:
# 2726

# %%
df['Item Name'].unique()
# Out:
# array(['Mineral Water', 'Chapathi (2 No)', 'Roti', 'Mushroom Pulao',
#        'Veg Fried Rice', 'Butter Scotch Scoop', 'Paneer Manchurian',
#        'Thandoor Chicken Full', 'Schezwan Chicken  Fried Rice',
#        'Sweet Corn Chicken Soup', 'Chicken Noodles', 'Lemon Soda',
#        'Pepper Garlic Chicken Soup', 'Mushroom - 65', 'Chicken Lolly Pop',
#        'French Fries', 'Chicken Fried Rice', 'Chicken 65', 'Butter Naan',
#        'Dragon Chicken', 'Paneer Butter Masala', 'Kadai Chicken',
#        'Soft Drink 600ml', 'Tea', 'Kozhicharru', 'Prawn Noodles',
#        'Schezwan Paneer', 'Chicken Biriyani With Raitha And Gravy',
#        'Egg Briyani With Raitha And Chicken Gravy',
#        'Schewan Veg Fried Rice', 'Gobi- 65', 'Blue Lagoon',
#        'Mixed Veg Pulao', 'Baby Corn 65', 'Chicken Manchurian Dry',
#        'Prawn 65', 'Fish Finger', 'Pichi Potta Kozhi Varuval',
#        'Schezwan Chicken Dry', 'Egg Noodles', 'Mixed Fried Rice',
# ...

# %%
df['Item Name'].nunique()
# Out:
# 222

# %%
df['Final Total'].sum()
# Out:
# 1188873.53

# %%
df['Final Total'].sum() / df['Invoice No.'].nunique()
# Out:
# 436.12381878209834

# %%
df['Discount'].sum()
# Out:
# 9287.71

# %%
df['Tax'].sum()
# Out:
# 56558.24

# %%
a =df['Discount'].sum() / df['Invoice No.'].nunique()
print(a)
# Out:
# 3.4070836390315478
